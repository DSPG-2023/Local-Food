# %%
from datetime import datetime
import pandas as pd
import scrapy
from scrapy.crawler import CrawlerProcess
from scrapy.utils.log import configure_logging
import time
class VanguardSpider(scrapy.Spider):
    name = 'Vanguard'
    def start_requests( self ):
        
        independenceUrls = ['https://buchanan.iowaassessors.com/results.php?sort_options=2&sort=0&mode=resbld&history=-1&occupancy1=&style1=&year1=&year2=&tla1=&tla2=&bedroom1=Equals&bedroom2=&ac1=&fireplace1=&bsmt1=&atticsf1=&atticsf2=&bsmtfin1=&bsmtfin2=&garatt1=&garatt2=&gardet1=&gardet2=&lot1=&lot2=&location1=&class1=2&dc=&maparea1=&dist1=5&appraised1=&appraised2=&sale_date1=&sale_date2=&sale_amt1=&sale_amt2=&nutc1=100%2C0%2C122%2C126%2C134%2C135%2C136%2C140%2C141%2C143%2C145%2C147%2C105%2C154%2C155%2C158%2C107%2C167%2C170%2C176%2C110%2C112%2C116' 
                           ] 
        for url in independenceUrls:
            yield scrapy.Request( url = url, callback = self.parsePage, meta={'DataFrameIndex': 0, 'URLIndex': 0})
        
    def parsePage(self, response):
        index = response.meta.get('DataFrameIndex')
        tableItemsXpath = '//*[@id="resultsWrapper" and contains(@class, "mobileHide")]//tr[contains(@class, "even") or contains(@class, "odd")]'
        XpathList = [
            './/td[1]/a/text()',    #Parcel Number Xpath
            './/td[2]/a/img/@src',  #Photo Xpath
            './/td[3]/text()',      #Address Xpath
            './/td[4]/text()',      #Style Xpath
            './/td[5]/text()',      #Year Built Xpath
            './/td[6]/text()',      #Total SF Xpath
            './/td[8]/text()',      #Lot Area Xpath
            './/td[8]/text()'       #Appraised Value Xpath
        ]  
        #Table
        for row in response.xpath(tableItemsXpath):
            cells = []
            for xpath in XpathList:
                cells.append(row.xpath(xpath).extract_first())
            # Special condition for cell 1 (Image)      
            cells.append(response.url)
            if cells[1]:
                cells[1] = response.follow(url=cells[1]).url
            DataFrame[index].loc[len(DataFrame[index])] = cells
        
        URLIndex = response.meta.get('URLIndex')
        newURLIndex = URLIndex+1
        
        # if not (newURLIndex % 20 == 0 or len(LoadURLs) < newURLIndex):
        # if len(LoadURLs) < newURLIndex:
        yield response.follow( url = LoadURLs[URLIndex], callback = self.parsePage, meta={'DataFrameIndex': index, 'URLIndex': newURLIndex})
    
# 84 len 
LoadURLs = [
    'https://buchanan.iowaassessors.com/results.php?page=1&history=-85&ts=1688575587'
    'https://buchanan.iowaassessors.com/results.php?page=2&history=-2&ts=1688575587',
    'https://buchanan.iowaassessors.com/results.php?page=3&history=-3&ts=1688575587',
    'https://buchanan.iowaassessors.com/results.php?page=4&history=-4&ts=1688575587',
    'https://buchanan.iowaassessors.com/results.php?page=5&history=-5&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=6&history=-6&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=7&history=-7&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=8&history=-8&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=9&history=-9&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=10&history=-10&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=11&history=-11&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=12&history=-12&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=13&history=-13&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=14&history=-14&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=15&history=-15&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=16&history=-16&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=17&history=-17&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=18&history=-18&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=19&history=-19&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=20&history=-20&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=21&history=-21&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=22&history=-22&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=23&history=-23&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=24&history=-24&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=25&history=-25&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=26&history=-26&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=27&history=-27&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=28&history=-28&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=29&history=-29&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=30&history=-30&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=31&history=-31&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=32&history=-32&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=33&history=-33&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=34&history=-34&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=35&history=-35&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=36&history=-36&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=37&history=-37&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=38&history=-38&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=39&history=-39&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=40&history=-40&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=41&history=-41&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=42&history=-42&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=43&history=-43&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=44&history=-44&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=45&history=-45&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=46&history=-46&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=47&history=-47&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=48&history=-48&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=49&history=-49&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=50&history=-50&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=51&history=-51&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=52&history=-52&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=53&history=-53&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=54&history=-54&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=55&history=-55&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=56&history=-56&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=57&history=-57&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=58&history=-58&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=59&history=-59&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=60&history=-60&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=61&history=-61&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=62&history=-62&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=63&history=-63&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=64&history=-64&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=65&history=-65&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=66&history=-66&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=67&history=-67&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=68&history=-68&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=69&history=-69&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=70&history=-70&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=71&history=-71&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=72&history=-72&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=73&history=-73&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=74&history=-74&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=75&history=-75&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=76&history=-76&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=77&history=-77&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=78&history=-78&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=79&history=-79&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=80&history=-80&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=81&history=-81&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=82&history=-82&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=83&history=-83&ts=1688576139',
    'https://buchanan.iowaassessors.com/results.php?page=84&history=-84&ts=1688576139'
]

# %%
#Start
DEBUG = False
#Data Frames
DataFrame = [
    pd.DataFrame(columns=['Parcel Number','Photo', 'Address', 'Style', 'Year Built', 'Total SF', 'Lot Area', 'Appraised Value', 'Url']) #independence
]
#Data Names
DataName = [
    "Independence.csv",
]

if(DEBUG):
    #To see the inner mechanics of the spider
    configure_logging()

#This is to start the spider
process = CrawlerProcess()
process.crawl(VanguardSpider)
process.start()
process.stop()
currentDate = str(datetime(datetime.today().year, datetime.today().month, datetime.today().day))[:-8]
for dataIndex, name in enumerate(DataName):
    print(DataFrame[dataIndex])
    DataFrame[dataIndex].to_csv(currentDate + name, index=False)
# Out:
# 2023-07-06 12:03:41 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: scrapybot)
# 2023-07-06 12:03:41 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 1.21.0, Twisted 22.2.0, Python 3.10.9 | packaged by conda-forge | (main, Jan 11 2023, 15:15:40) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 22.0.0 (OpenSSL 1.1.1u  30 May 2023), cryptography 37.0.1, Platform Windows-10-10.0.19045-SP0
# 2023-07-06 12:03:41 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-07-06 12:03:41 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-07-06 12:03:41 [scrapy.extensions.telnet] INFO: Telnet Password: f81965efd474ce08
# 2023-07-06 12:03:41 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2023-07-06 12:03:42 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ...
